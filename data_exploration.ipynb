# %%
import pandas as pd

Athlete_events = pd.read_csv("Data/athlete_events.csv")
Noc_regions = pd.read_csv("Data/noc_regions.csv")

df_athlete = pd.DataFrame(Athlete_events)
df_regions = pd.DataFrame(Noc_regions)

# %%
# NOTE: skriv enhetligt

# %% [markdown]
# # Looking at Regions

# %%
df_regions # looking at df_regions
# we can see there are 2 Yemen
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
len(df_regions["region"].unique()) # unique regions in regions
# Out:
# 207

# %%
df_regions[df_regions["region"].isna() == True] # nan values in region
# Out:
#      NOC region                 notes
# 168  ROT    NaN  Refugee Olympic Team
# 208  TUV    NaN                Tuvalu
# 213  UNK    NaN               Unknown

# %%
df_regions[df_regions["notes"].notna() == True].reset_index(drop = True) # all notes in dataframe
# might have to remove unknown, is "Individual Olympic Athletes" actually a region for example?
# Out:
#     NOC                       region                        notes
# 0   AHO                      Curacao         Netherlands Antilles
# 1   ANT                      Antigua          Antigua and Barbuda
# 2   ANZ                    Australia                  Australasia
# 3   BOH               Czech Republic                      Bohemia
# 4   CRT                       Greece                        Crete
# 5   HKG                        China                    Hong Kong
# 6   IOA  Individual Olympic Athletes  Individual Olympic Athletes
# 7   ISV           Virgin Islands, US               Virgin Islands
# 8   NBO                     Malaysia                 North Borneo
# 9   NFL                       Canada                 Newfoundland
# 10  ROT                          NaN         Refugee Olympic Team
# 11  SCG                       Serbia        Serbia and Montenegro
# 12  SKN                  Saint Kitts     Turks and Caicos Islands
# ...

# %%
# NOTE regex filter out olympic from regions, search strings containing instead of absolute match
# Out:
# Empty DataFrame
# Columns: [NOC, region, notes]
# Index: []

# %%
df_regions[df_regions["region"].isin(["Russia"])] # there are multiple versions of the same country in some cases
# Out:
#      NOC  region notes
# 66   EUN  Russia   NaN
# 171  RUS  Russia   NaN
# 214  URS  Russia   NaN

# %%
df_regions[df_regions["region"].isin(["Yemen"])] # looking at some specific examples
# Out:
#      NOC region        notes
# 224  YAR  Yemen  North Yemen
# 225  YEM  Yemen          NaN
# 226  YMD  Yemen  South Yemen

# %%
df_regions[df_regions["region"].isin(["Sudan", "South Sudan", "Kosovo", "Palestine", "Taiwan"])] # looking at some specific examples
# Out:
#      NOC       region notes
# 110  KOS       Kosovo   NaN
# 159  PLE    Palestine   NaN
# 187  SSD  South Sudan   NaN
# 189  SUD        Sudan   NaN
# 204  TPE       Taiwan   NaN

# %% [markdown]
# # Looking at Athletes

# %%
df_athlete
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df_athlete.info() # there are some nans for age, height and weight, theory: they will be mostly from older records where records were not kept as closely
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df_athlete[df_athlete["Age"].isna() == True].sort_values(by = "Year", ascending = False) # missing age from mostly older records
# Out:
#            ID                           Name Sex  Age  Height  Weight  \
# 37946   19504                   Cha Yong-Hwa   F  NaN   145.0    39.0
# 37945   19504                   Cha Yong-Hwa   F  NaN   145.0    39.0
# 162719  81706                        Moosaka   F  NaN     NaN     NaN
# 142614  71557  Christopher Paul "Chris" Lori   M  NaN     NaN     NaN
# 142615  71557  Christopher Paul "Chris" Lori   M  NaN     NaN     NaN
# ...       ...                            ...  ..  ...     ...     ...
# 113380  57436           Tilemakhos Karakalos   M  NaN     NaN     NaN
# 113390  57440                   Karakatsanis   M  NaN     NaN     NaN
# 113391  57441      Konstantinos Karakatsanis   M  NaN     NaN     NaN
# 160372  80474            Ioannis Mitropoulos   M  NaN     NaN     NaN
# 181291  91114                     Pantazidis   M  NaN     NaN     NaN
#
#                Team  NOC        Games  Year  Season     City         Sport  \
# ...

# %%
df_athlete[df_athlete["Height"].isna() == True].sort_values(by = "Year", ascending = False) # missing height in more recent years
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 76691    38935             Tigest Gashaw Belay   F  19.0     NaN     NaN
# 83371    42358         Naomy Hope Grand'Pierre   F  19.0     NaN     NaN
# 83735    42568                     Kyle Greaux   M  28.0     NaN     NaN
# 195175   97968  Rebeca Lissette Quinteros Ortz   F  18.0     NaN     NaN
# 152078   76331                 Emmanuel Matadi   M  25.0     NaN     NaN
# ...        ...                             ...  ..   ...     ...     ...
# 77782    39487             Georgios Gennimatas   M   NaN     NaN     NaN
# 258828  129584             Joseph Welzenbacher   M   NaN     NaN     NaN
# 258829  129584             Joseph Welzenbacher   M   NaN     NaN     NaN
# 114592   58020                     N. Katravas   M   NaN     NaN     NaN
# 23916    12563       Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
#
#                        Team  NOC        Games  Year  Season            City  \
# ...

# %%
df_athlete[df_athlete["Year"] > 2000].sort_values(by = "Year", ascending = False).head(50)
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 129782   65337                     Yusaku Kuwazuru   M  30.0   188.0    98.0
# 40186    20661                     Eunice Chibanda   F  23.0   163.0    61.0
# 177674   89298                        Stefano Oppo   M  21.0   187.0    70.0
# 40141    20643           Izabella Maizza Chiappini   F  20.0   170.0    59.0
# 89096    45164                     Ham Sang-Myeong   M  20.0   168.0    56.0
# 40144    20645                   Andrea Chiarabini   M  21.0   179.0    70.0
# 40145    20645                   Andrea Chiarabini   M  21.0   179.0    70.0
# 177677   89300                         Laura Oprea   F  22.0   186.0    75.0
# 40149    20647    Germn Pablo Chiaraviglio Ermcora   M  29.0   195.0    84.0
# 229183  115074         Evelyn Lee Stevens (-Baker)   F  33.0   166.0    55.0
# 229182  115074         Evelyn Lee Stevens (-Baker)   F  33.0   166.0    55.0
# ...

# %%
df_athlete["Games"].isin(["2016 Summer"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Games, Length: 271116, dtype: bool

# %%
cond = ["2014 Winter"]

df_athlete[df_athlete["Games"].isin(cond)]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 40          16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 252        126            Forough Abbasi   F  20.0   164.0    58.0
# 277        145             Jeremy Abbott   M  28.0   175.0    70.0
# 278        145             Jeremy Abbott   M  28.0   175.0    70.0
# 809        463             Agnese boltia   F  17.0   166.0    60.0
# ...        ...                       ...  ..   ...     ...     ...
# 270930  135485    Stepan Olegovich Zuyev   M  25.0   189.0    90.0
# 270966  135500        Kristaps Zvejnieks   M  21.0   185.0    87.0
# 270967  135500        Kristaps Zvejnieks   M  21.0   185.0    87.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
#
#                  Team  NOC        Games  Year  Season   City           Sport  \
# 40            Finland  FIN  2014 Winter  2014  Winter  Sochi      Ice Hockey
# ...

# %%
# NOC will be our connection to countries from the region df
# TODO check whether to include all 3 connections for Russia for example
# NOTE seems to be mostly older records that are inconsistent in formatting, see below for examples:

# %%
df_athlete[df_athlete["Name"] == "Edgar Lindenau Aabye"] # year 1900
# Out:
#    ID                  Name Sex   Age  Height  Weight            Team  NOC  \
# 3   4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
#
#          Games  Year  Season   City       Sport                        Event  \
# 3  1900 Summer  1900  Summer  Paris  Tug-Of-War  Tug-Of-War Men's Tug-Of-War
#
#   Medal
# 3  Gold

# %%
df_athlete[df_athlete["Name"] == "Andrzej ya"] # year 1976
# Out:
#             ID        Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569  Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
#
#               Games  Year  Season       City Sport  \
# 271111  1976 Winter  1976  Winter  Innsbruck  Luge
#
#                              Event Medal
# 271111  Luge Mixed (Men)'s Doubles   NaN

# %%
len(df_athlete["Team"].unique())
# Out:
# 1184

# %%
df_athlete["Team"].unique()
# Out:
# array(['China', 'Denmark', 'Denmark/Sweden', ..., 'Solos Carex',
#        'Dow Jones', 'Digby'], dtype=object)

# %%
# checking if teams could be a better representative of countries
df_athlete["Team"].drop_duplicates() #
# Out:
# 0                  China
# 2                Denmark
# 3         Denmark/Sweden
# 4            Netherlands
# 10         United States
#                ...
# 259381         Sea Dog-2
# 259975             Mainz
# 260675       Solos Carex
# 264108         Dow Jones
# 270564             Digby
# Name: Team, Length: 1184, dtype: object
